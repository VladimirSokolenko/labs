# %% [markdown]
# ## Introduction
# -----
#
# In this assignment you will recursively estimate the position of a vehicle along a trajectory using available measurements and a motion model.
#
# The vehicle is equipped with a very simple type of LIDAR sensor, which returns range and bearing measurements corresponding to individual landmarks in the environment. The global positions of the landmarks are assumed to be known beforehand. We will also assume known data association, that is, which measurment belong to which landmark.
#
# ## Motion and Measurement Models
# -----
#
# ### Motion Model
#
# The vehicle motion model recieves linear and angular velocity odometry readings as inputs, and outputs the state (i.e., the 2D pose) of the vehicle:
#
# \begin{align}
# \mathbf{x}_{k} &= \mathbf{x}_{k-1} + T
# \begin{bmatrix}
# \cos\theta_{k-1} &0 \\
# \sin\theta_{k-1} &0 \\
# 0 &1
# \end{bmatrix}
# \left(
# \begin{bmatrix}
# v_k \\
# \omega_k
# \end{bmatrix}
# + \mathbf{w}_k
# \right)
# \, , \, \, \, \, \, \mathbf{w}_k = \mathcal{N}\left(\mathbf{0}, \mathbf{Q}\right)
# \end{align}
#
# - $\mathbf{x}_k = \left[ x \, y \, \theta \right]^T$ is the current 2D pose of the vehicle
# - $v_k$ and $\omega_k$ are the linear and angular velocity odometry readings, which we use as inputs to the model
#
# The process noise $\mathbf{w}_k$ has a (zero mean) normal distribution with a constant covariance $\mathbf{Q}$.
#
# ### Measurement Model
#
# The measurement model relates the current pose of the vehicle to the LIDAR range and bearing measurements $\mathbf{y}^l_k = \left[r \, \phi \right]^T$.
#
# \begin{align}
# \mathbf{y}^l_k =
# \begin{bmatrix}
# \sqrt{(x_l - x_k - d\cos\theta_{k})^2 + (y_l - y_k - d\sin\theta_{k})^2} \\
# atan2\left(y_l - y_k - d\sin\theta_{k},x_l - x_k - d\cos\theta_{k}\right) - \theta_k
# \end{bmatrix}
# +
# \mathbf{n}^l_k
# \, , \, \, \, \, \, \mathbf{n}^l_k = \mathcal{N}\left(\mathbf{0}, \mathbf{R}\right)
# \end{align}
#
# - $x_l$ and $y_l$ are the ground truth coordinates of the landmark $l$
# - $x_k$ and $y_k$ and $\theta_{k}$ represent the current pose of the vehicle
# - $d$ is the known distance between robot center and laser rangefinder (LIDAR)
#
# The landmark measurement noise $\mathbf{n}^l_k$ has a (zero mean) normal distribution with a constant covariance $\mathbf{R}$.
#
# ## Getting Started
# -----
#
# Since the models above are nonlinear, we recommend using the extended Kalman filter (EKF) as the state estimator.
# Specifically, you will need to provide code implementing the following steps:
# - the prediction step, which uses odometry measurements and the motion model to produce a state and covariance estimate at a given timestep, and
# - the correction step, which uses the range and bearing measurements provided by the LIDAR to correct the pose and pose covariance estimates
#
# ### Unpack the Data
# First, let's unpack the available data:

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

with open('data/data.pickle', 'rb') as f:
    data = pickle.load(f)

t = data['t']  # timestamps [s]

x_init  = data['x_init'] # initial x position [m]
y_init  = data['y_init'] # initial y position [m]
th_init = data['th_init'] # initial theta position [rad]

# input signal
v  = data['v']  # translational velocity input [m/s]
om = data['om']  # rotational velocity input [rad/s]

# bearing and range measurements, LIDAR constants
b = data['b']  # bearing to each landmarks center in the frame attached to the laser [rad]
r = data['r']  # range measurements [m]
l = data['l']  # x,y positions of landmarks [m]
d = data['d']  # distance between robot center and laser rangefinder [m]

# %% [markdown]
# Note that distance from the LIDAR frame to the robot center is provided and loaded as an array into the `d` variable.
#
# ### Ground Truth
# If available, it is useful to plot the ground truth position and orientation before starting the assignment.
#
# <table><tr>
# <td> <img src="data/gtruth.png" alt="Ground Truth" width="350"/> </td>
# <td> <img src="data/gtruth2.png" alt="Ground Truth" width="350"/> </td>
# </tr></table>
#
# Notice that the orientation values are wrapped to the $\left[-\pi,\pi\right]$ range in radians.

# %% [markdown]
# ### Initializing Parameters
#
# Now that our data is loaded, we can begin getting things set up for our solver. One of the
# most important aspects of designing a filter is determining the input and measurement noise covariance matrices, as well as the initial state and covariance values. We set the values here:

# %%
v_var = 0.01  # translation velocity variance  
om_var = 0.01  # rotational velocity variance 
r_var = 0.1  # range measurements variance
b_var = 0.1  # bearing measurement variance

Q_km = np.diag([v_var, om_var]) # input noise covariance 
cov_y = np.diag([r_var, b_var])  # measurement noise covariance 

x_est = np.zeros([len(v), 3])  # estimated states, x, y, and theta
P_est = np.zeros([len(v), 3, 3])  # state covariance matrices

x_est[0] = np.array([x_init, y_init, th_init]) # initial state
P_est[0] = np.diag([1, 1, 0.1]) # initial state covariance

# %% [markdown]
# **Remember:** that it is neccessary to tune the measurement noise variances `r_var`, `b_var` in order for the filter to perform well!
#
# In order for the orientation estimates to coincide with the bearing measurements, it is also neccessary to wrap all estimated $\theta$ values to the $(-\pi , \pi]$ range.

# %%
# Wraps angle to (-pi,pi] range
def wraptopi(x):
    if x > np.pi:
        x = x - (np.floor(x / (2 * np.pi)) + 1) * 2 * np.pi
    elif x < -np.pi:
        x = x + (np.floor(x / (-2 * np.pi)) + 1) * 2 * np.pi
    return x


def modulo_pi(x):
       return (x + np.pi) % (2 * np.pi) - np.pi

# %% [markdown]
# ## Correction Step
# -----
# First, let's implement the measurement update function, which takes an available landmark measurement $l$ and updates the current state estimate $\mathbf{\check{x}}_k$.
# For each landmark measurement received at a given timestep $k$, you should implement the following steps:
#
# - Compute the measurement model Jacobians at $\mathbf{\check{x}}_{k}$
# \begin{align}
# \mathbf{y}^l_k = &\mathbf{h}(\mathbf{x}_{k}, \mathbf{n}^l_k) \\\\
# \mathbf{H}_{k} = \frac{\partial \mathbf{h}}{\partial \mathbf{x}_{k}}\bigg|_{\mathbf{\check{x}}_{k},0}& \, , \, \, \, \,
# \mathbf{M}_{k} = \frac{\partial \mathbf{h}}{\partial \mathbf{n}_{k}}\bigg|_{\mathbf{\check{x}}_{k},0} \, .
# \end{align}
# - Compute the Kalman Gain
# \begin{align}
# \mathbf{K}_k &= \mathbf{\check{P}}_k \mathbf{H}_k^T \left(\mathbf{H}_k \mathbf{\check{P}}_k \mathbf{H}_k^T + \mathbf{M}_k \mathbf{R}_k \mathbf{M}_k^T \right)^{-1}
# \end{align}
# - Correct the predicted state
# \begin{align}
# \mathbf{\check{y}}^l_k &= \mathbf{h}\left(\mathbf{\check{x}}_k, \mathbf{0}\right) \\
# \mathbf{\hat{x}}_k &= \mathbf{\check{x}}_k + \mathbf{K}_k \left(\mathbf{y}^l_k - \mathbf{\check{y}}^l_k\right)
# \end{align}
# - Correct the covariance
# \begin{align}
# \mathbf{\hat{P}}_k &= \left(\mathbf{I} - \mathbf{K}_k \mathbf{H}_k \right)\mathbf{\check{P}}_k
# \end{align}

# %%
def measurement_update(lk, rk, bk, P_check, x_check):
    
    x_k = x_check[0]
    y_k = x_check[1]
    theta_k = wraptopi(x_check[2])
    
    x_l = lk[0]
    y_l = lk[1]
    
    d_x = x_l - x_k - d*np.cos(theta_k)
    d_y = y_l - y_k - d*np.sin(theta_k)
    
    r = np.sqrt(d_x**2 + d_y**2)
    phi = np.arctan2(d_y, d_x) - theta_k

    # 1. Compute measurement Jacobian
    H_k = np.zeros((2,3))
    H_k[0,0] = -d_x/r
    H_k[0,1] = -d_y/r
    H_k[0,2] = d*(d_x*np.sin(theta_k) - d_y*np.cos(theta_k))/r
    H_k[1,0] = d_y/r**2
    H_k[1,1] = -d_x/r**2
    H_k[1,2] = -1-d*(d_y*np.sin(theta_k) + d_x*np.cos(theta_k))/r**2
    
    M_k = np.identity(2)
    
    # y_out = np.vstack([r, wraptopi(phi)])
    # y_mes = np.vstack([rk, wraptopi(bk)])
    y_out = np.vstack([r, modulo_pi(phi)])
    y_mes = np.vstack([rk, modulo_pi(bk)])

    # 2. Compute Kalman Gain
    K_k = P_check.dot(H_k.T).dot(np.linalg.inv(H_k.dot(P_check).dot(H_k.T) + M_k.dot(cov_y).dot(M_k.T)))

    # 3. Correct predicted state (remember to wrap the angles to [-pi,pi])
    x_check = x_check + K_k.dot(y_mes - y_out)
    # x_check[2] = wraptopi(x_check[2])
    x_check[2] = modulo_pi(x_check[2])

    # 4. Correct covariance
    P_check = (np.identity(3) - K_k.dot(H_k)).dot(P_check)

    return x_check, P_check

# %% [markdown]
# ## Prediction Step
# -----
# Now, implement the main filter loop, defining the prediction step of the EKF using the motion model provided:
#
# \begin{align}
# \mathbf{\check{x}}_k &= \mathbf{f}\left(\mathbf{\hat{x}}_{k-1}, \mathbf{u}_{k-1}, \mathbf{0} \right) \\
# \mathbf{\check{P}}_k &= \mathbf{F}_{k-1}\mathbf{\hat{P}}_{k-1}\mathbf{F}_{k-1}^T + \mathbf{L}_{k-1}\mathbf{Q}_{k-1}\mathbf{L}_{k-1}^T \, .
# \end{align}
#
# Where
#
# \begin{align}
# \mathbf{F}_{k-1} = \frac{\partial \mathbf{f}}{\partial \mathbf{x}_{k-1}}\bigg|_{\mathbf{\hat{x}}_{k-1},\mathbf{u}_{k},0}  \, , \, \, \, \,
# \mathbf{L}_{k-1} = \frac{\partial \mathbf{f}}{\partial \mathbf{w}_{k}}\bigg|_{\mathbf{\hat{x}}_{k-1},\mathbf{u}_{k},0} \, .
# \end{align}

# %%
# def modulo_pi(x):
#        return (x + np.pi) % (2 * np.pi) - np.pi
# step = 0.01
# print(np.pi)
# print(int(10 * np.pi // step))
# steps_cnt = int(10 * np.pi // step)
# theta = np.zeros(steps_cnt)
# om = -5*np.pi
# for i in range(steps_cnt):
#     # theta[i] = wraptopi(om)
#     theta[i] = modulo_pi(om)
#     om += step
# plt.plot(theta)
# plt.show()

# %%
#### 5. Main Filter Loop #######################################################################
# set the initial values
P_check = P_est[0]
x_check = x_est[0, :].reshape(3,1)

for k in range(1, len(t)):  # start at 1 because we've set the initial prediciton

    delta_t = t[k] - t[k - 1]  # time step (difference between timestamps)
    # theta = wraptopi(x_check[2])
    theta = modulo_pi(x_check[2])

    print(f'theta: {theta}')
    print(f'np.cos(theta)[0]: {np.cos(theta)[0]}')

    # 1. Update state with odometry readings (remember to wrap the angles to [-pi,pi])
    # x_check = np.zeros(3)
    F = np.array([[np.cos(theta)[0], 0],
                  [np.sin(theta)[0], 0],
                  [0, 1]], dtype='float')
    
    inp = np.array([[v[k-1]], [om[k-1]]])

    x_check = x_check + F.dot(inp).dot(delta_t)

    # x_check[2] = wraptopi(x_check[2])
    x_check[2] = modulo_pi(x_check[2])

    # 2. Motion model jacobian with respect to last state
    # F_km = np.zeros([3, 3])
    print(f'-np.sin(theta)*delta_t*v[k-1]: {-(np.sin(theta)*delta_t*v[k-1])[0]}')

    F_km = np.array([[1, 0, -(np.sin(theta)*delta_t*v[k-1])[0]],
                     [0, 1, (np.cos(theta)*delta_t*v[k-1])[0]],
                     [0, 0, 1]], dtype='float')

    # 3. Motion model jacobian with respect to noise
    # L_km = np.zeros([3, 2])
    L_km = np.array([[(np.cos(theta)*delta_t)[0], 0], 
                    [(np.sin(theta)*delta_t)[0], 0],
                    [0,1]], dtype='float')

    # 4. Propagate uncertainty
    P_check = F_km.dot(P_check.dot(F_km.T)) + L_km.dot(Q_km.dot(L_km.T))

    # 5. Update state estimate using available landmark measurements
    for i in range(len(r[k])):
        x_check, P_check = measurement_update(l[i], r[k, i], b[k, i], P_check, x_check)

    # Set final state predictions for timestep
    x_est[k, 0] = x_check[0]
    x_est[k, 1] = x_check[1]
    x_est[k, 2] = x_check[2]
    P_est[k, :, :] = P_check
# Out:
# theta: [1.57079633]
# np.cos(theta)[0]: 6.123233995736766e-17
# -np.sin(theta)*delta_t*v[k-1]: -0.6810786592005811
# theta: [1.62436377]
# np.cos(theta)[0]: -0.05354182490158168
# -np.sin(theta)*delta_t*v[k-1]: -0.6954834921607911
# theta: [1.63920895]
# np.cos(theta)[0]: -0.06835926981843508
# -np.sin(theta)*delta_t*v[k-1]: -0.58768417176834
# theta: [1.6497528]
# np.cos(theta)[0]: -0.0788744603249964
# -np.sin(theta)*delta_t*v[k-1]: -0.5755706420097271
# theta: [1.74982893]
# np.cos(theta)[0]: -0.1780777182812155
# -np.sin(theta)*delta_t*v[k-1]: -0.6289908890746597
# theta: [1.73705831]
# np.cos(theta)[0]: -0.16549704724790162
# -np.sin(theta)*delta_t*v[k-1]: -0.6021590514670598
# theta: [1.708439]
# np.cos(theta)[0]: -0.13720846346842802
# -np.sin(theta)*delta_t*v[k-1]: -0.7186361634299873
# theta: [1.66765747]
# np.cos(theta)[0]: -0.09670975869220966
# -np.sin(theta)*delta_t*v[k-1]: -0.735006617341858
# theta: [1.73653858]
# np.cos(theta)[0]: -0.1649844530429993
# -np.sin(theta)*delta_t*v[k-1]: -0.5306772812545479
# theta: [1.72325055]
# np.cos(theta)[0]: -0.1518643479638415
# -np.sin(theta)*delta_t*v[k-1]: -0.5181452788537517
# theta: [1.77885277]
# np.cos(theta)[0]: -0.2065586503231194
# -np.sin(theta)*delta_t*v[k-1]: -0.6477082736518818
# theta: [1.7495382]
# np.cos(theta)[0]: -0.17779162793219022
# -np.sin(theta)*delta_t*v[k-1]: -0.5749153001293701
# theta: [1.74848777]
# np.cos(theta)[0]: -0.17675784392592936
# -np.sin(theta)*delta_t*v[k-1]: -0.5310477860527456
# theta: [1.73576276]
# np.cos(theta)[0]: -0.1642192193276983
# -np.sin(theta)*delta_t*v[k-1]: -0.4855269492926833
# theta: [1.79429598]
# np.cos(theta)[0]: -0.22164357850332075
# -np.sin(theta)*delta_t*v[k-1]: -0.66594983383117
# theta: [1.79238441]
# np.cos(theta)[0]: -0.2197791513789787
# -np.sin(theta)*delta_t*v[k-1]: -0.6233020518696443
# theta: [1.76022435]
# np.cos(theta)[0]: -0.18829718199479809
# -np.sin(theta)*delta_t*v[k-1]: -0.6016462972376199
# theta: [1.77490919]
# np.cos(theta)[0]: -0.2026985182274416
# -np.sin(theta)*delta_t*v[k-1]: -0.6753551150601074
# theta: [1.36532627]
# np.cos(theta)[0]: 0.20402735581766387
# -np.sin(theta)*delta_t*v[k-1]: -0.6353084631441634
# theta: [1.70872242]
# np.cos(theta)[0]: -0.13748920491561203
# -np.sin(theta)*delta_t*v[k-1]: -0.6906250050724694
# theta: [1.3397427]
# np.cos(theta)[0]: 0.22900327569622483
# -np.sin(theta)*delta_t*v[k-1]: -0.5037856802842071
# theta: [1.258215]
# np.cos(theta)[0]: 0.30751589742052304
# -np.sin(theta)*delta_t*v[k-1]: -0.6235925598599787
# theta: [1.19638056]
# np.cos(theta)[0]: 0.3657288369883783
# -np.sin(theta)*delta_t*v[k-1]: -0.5322722471927713
# theta: [1.27720429]
# np.cos(theta)[0]: 0.28939242421533395
# -np.sin(theta)*delta_t*v[k-1]: -0.5405214007495559
# theta: [1.21146629]
# np.cos(theta)[0]: 0.3516471347350779
# -np.sin(theta)*delta_t*v[k-1]: -0.44988432335164397
# theta: [1.17844714]
# np.cos(theta)[0]: 0.3823601514594592
# -np.sin(theta)*delta_t*v[k-1]: -0.4478545321819389
# theta: [1.21254158]
# np.cos(theta)[0]: 0.35064032175349363
# -np.sin(theta)*delta_t*v[k-1]: -0.4342299523503547
# theta: [1.32314892]
# np.cos(theta)[0]: 0.2451238216488434
# -np.sin(theta)*delta_t*v[k-1]: -0.5299070307364251
# theta: [1.29677935]
# np.cos(theta)[0]: 0.27060071605170327
# -np.sin(theta)*delta_t*v[k-1]: -0.45165902051055706
# theta: [1.36538743]
# np.cos(theta)[0]: 0.20396747647172245
# -np.sin(theta)*delta_t*v[k-1]: -0.47232073367902394
# theta: [1.43129344]
# np.cos(theta)[0]: 0.13905085093579986
# -np.sin(theta)*delta_t*v[k-1]: -0.5012687421089067
# theta: [1.43250733]
# np.cos(theta)[0]: 0.13784865321525203
# -np.sin(theta)*delta_t*v[k-1]: -0.5404315378113679
# theta: [1.41549431]
# np.cos(theta)[0]: 0.15467849134670533
# -np.sin(theta)*delta_t*v[k-1]: -0.6140115393591362
# theta: [1.40256263]
# np.cos(theta)[0]: 0.16744124602411548
# -np.sin(theta)*delta_t*v[k-1]: -0.4406753764084909
# theta: [1.43425461]
# np.cos(theta)[0]: 0.1361178371422459
# -np.sin(theta)*delta_t*v[k-1]: -0.5135380489318769
# theta: [1.39985979]
# np.cos(theta)[0]: 0.1701053102579161
# -np.sin(theta)*delta_t*v[k-1]: -0.4830068364128632
# theta: [1.91954006]
# np.cos(theta)[0]: -0.341717437565062
# -np.sin(theta)*delta_t*v[k-1]: -0.34409817234106777
# theta: [2.14166916]
# np.cos(theta)[0]: -0.5403666818623483
# -np.sin(theta)*delta_t*v[k-1]: -0.36687871882228257
# theta: [2.21704755]
# np.cos(theta)[0]: -0.6021978210977865
# -np.sin(theta)*delta_t*v[k-1]: -0.4244870810594084
# theta: [2.28384476]
# np.cos(theta)[0]: -0.6541425508054544
# -np.sin(theta)*delta_t*v[k-1]: -0.31145215798582615
# theta: [2.32577183]
# np.cos(theta)[0]: -0.6852708271368178
# -np.sin(theta)*delta_t*v[k-1]: -0.28551747780034126
# theta: [2.37696441]
# np.cos(theta)[0]: -0.7216397632457813
# -np.sin(theta)*delta_t*v[k-1]: -0.3730834552016878
# theta: [2.43291404]
# np.cos(theta)[0]: -0.7592225408050272
# -np.sin(theta)*delta_t*v[k-1]: -0.24466071001164025
# theta: [2.45401598]
# np.cos(theta)[0]: -0.7727862883437272
# -np.sin(theta)*delta_t*v[k-1]: -0.2779829107284607
# theta: [2.45633191]
# np.cos(theta)[0]: -0.774254052219336
# -np.sin(theta)*delta_t*v[k-1]: -0.2625294704509019
# theta: [2.48520925]
# np.cos(theta)[0]: -0.7922044592375839
# -np.sin(theta)*delta_t*v[k-1]: -0.23348966521318837
# theta: [2.50370183]
# np.cos(theta)[0]: -0.8033535619977508
# -np.sin(theta)*delta_t*v[k-1]: -0.17877905885175902
# theta: [2.50401058]
# np.cos(theta)[0]: -0.803537388770621
# -np.sin(theta)*delta_t*v[k-1]: -0.19372382147226874
# theta: [2.55350467]
# np.cos(theta)[0]: -0.832002931327471
# -np.sin(theta)*delta_t*v[k-1]: -0.2679113022116447
# theta: [2.63448208]
# np.cos(theta)[0]: -0.8741514126172968
# -np.sin(theta)*delta_t*v[k-1]: -0.17140361290689074
# theta: [2.64395742]
# np.cos(theta)[0]: -0.8787138352246855
# -np.sin(theta)*delta_t*v[k-1]: -0.13867149467654552
# theta: [2.67337842]
# np.cos(theta)[0]: -0.8923756133046403
# -np.sin(theta)*delta_t*v[k-1]: -0.23171130802034035
# theta: [2.73908136]
# np.cos(theta)[0]: -0.9200801487393317
# -np.sin(theta)*delta_t*v[k-1]: -0.17973126118725477
# theta: [2.74552186]
# np.cos(theta)[0]: -0.9225839841027559
# -np.sin(theta)*delta_t*v[k-1]: -0.1290010055715135
# theta: [2.74982631]
# np.cos(theta)[0]: -0.9242360746600372
# -np.sin(theta)*delta_t*v[k-1]: -0.17103304218158405
# theta: [2.76710999]
# np.cos(theta)[0]: -0.9306969831493603
# -np.sin(theta)*delta_t*v[k-1]: -0.16589040627848708
# theta: [2.85523777]
# np.cos(theta)[0]: -0.9592798353564463
# -np.sin(theta)*delta_t*v[k-1]: -0.11914929183220349
# theta: [2.86008158]
# np.cos(theta)[0]: -0.9606367484894616
# -np.sin(theta)*delta_t*v[k-1]: -0.1078507611425391
# theta: [2.85286241]
# np.cos(theta)[0]: -0.9586061933507734
# -np.sin(theta)*delta_t*v[k-1]: -0.11514868337942934
# theta: [2.93803415]
# np.cos(theta)[0]: -0.9793534092279579
# -np.sin(theta)*delta_t*v[k-1]: -0.0739166463469881
# theta: [3.05142637]
# np.cos(theta)[0]: -0.9959377741949954
# -np.sin(theta)*delta_t*v[k-1]: -0.032651865162479886
# theta: [-3.13503001]
# np.cos(theta)[0]: -0.9999784658995826
# -np.sin(theta)*delta_t*v[k-1]: 0.0025083866574173806
# theta: [3.13824156]
# np.cos(theta)[0]: -0.9999943850818622
# -np.sin(theta)*delta_t*v[k-1]: -0.0012090417771960017
# theta: [-3.07607842]
# np.cos(theta)[0]: -0.9978547103041449
# -np.sin(theta)*delta_t*v[k-1]: 0.03153068067896989
# theta: [-3.0577128]
# np.cos(theta)[0]: -0.9964841468925707
# -np.sin(theta)*delta_t*v[k-1]: 0.027778940974259266
# theta: [-3.10319809]
# np.cos(theta)[0]: -0.9992630192371978
# -np.sin(theta)*delta_t*v[k-1]: 0.01751718519223233
# theta: [-3.07456371]
# np.cos(theta)[0]: -0.9977544009831935
# -np.sin(theta)*delta_t*v[k-1]: 0.025415314291933864
# theta: [-2.97760152]
# np.cos(theta)[0]: -0.9865835623575383
# -np.sin(theta)*delta_t*v[k-1]: 0.07801088665256492
# theta: [-2.97288306]
# np.cos(theta)[0]: -0.9858022607545477
# -np.sin(theta)*delta_t*v[k-1]: 0.08429558116486811
# theta: [-2.86918497]
# np.cos(theta)[0]: -0.9631258981072047
# -np.sin(theta)*delta_t*v[k-1]: 0.14219835115944096
# theta: [-2.88859834]
# np.cos(theta)[0]: -0.9681672730491818
# -np.sin(theta)*delta_t*v[k-1]: 0.14222646838172265
# theta: [-2.91641647]
# np.cos(theta)[0]: -0.9747547834260576
# -np.sin(theta)*delta_t*v[k-1]: 0.10817994725507471
# theta: [-2.9093778]
# np.cos(theta)[0]: -0.9731590706717456
# -np.sin(theta)*delta_t*v[k-1]: 0.11300326455529322
# theta: [-2.83700015]
# np.cos(theta)[0]: -0.9539692407302198
# -np.sin(theta)*delta_t*v[k-1]: 0.1534193542656659
# theta: [-2.77595432]
# np.cos(theta)[0]: -0.9338957164325012
# -np.sin(theta)*delta_t*v[k-1]: 0.18620910183812422
# theta: [-2.75075851]
# np.cos(theta)[0]: -0.9245916056684907
# -np.sin(theta)*delta_t*v[k-1]: 0.18547680891648782
# theta: [-2.79327268]
# np.cos(theta)[0]: -0.9399474648779599
# -np.sin(theta)*delta_t*v[k-1]: 0.18712328492304608
# theta: [-2.73338352]
# np.cos(theta)[0]: -0.9178332087299778
# -np.sin(theta)*delta_t*v[k-1]: 0.23034599260951133
# theta: [-2.66915141]
# np.cos(theta)[0]: -0.8904600247515299
# -np.sin(theta)*delta_t*v[k-1]: 0.29554186538806676
# theta: [-2.70662044]
# np.cos(theta)[0]: -0.9068817525002171
# -np.sin(theta)*delta_t*v[k-1]: 0.25400277097026497
# theta: [-2.6346875]
# np.cos(theta)[0]: -0.8742511598448334
# -np.sin(theta)*delta_t*v[k-1]: 0.29576192338657614
# theta: [-2.64232803]
# np.cos(theta)[0]: -0.8779348810816385
# -np.sin(theta)*delta_t*v[k-1]: 0.2502126396376516
# theta: [-2.63166362]
# np.cos(theta)[0]: -0.8727791512956441
# -np.sin(theta)*delta_t*v[k-1]: 0.37958860069745315
# theta: [-2.7006819]
# np.cos(theta)[0]: -0.9043633642514641
# -np.sin(theta)*delta_t*v[k-1]: 0.23260936581207345
# theta: [-2.6923981]
# np.cos(theta)[0]: -0.9007971512028641
# -np.sin(theta)*delta_t*v[k-1]: 0.25446010341740066
# theta: [-2.66030563]
# np.cos(theta)[0]: -0.8863998675246024
# -np.sin(theta)*delta_t*v[k-1]: 0.2935052886994165
# theta: [-2.64917352]
# np.cos(theta)[0]: -0.8811917705911215
# -np.sin(theta)*delta_t*v[k-1]: 0.3468057534057793
# theta: [-2.58726528]
# np.cos(theta)[0]: -0.85025468320784
# -np.sin(theta)*delta_t*v[k-1]: 0.3756083252347613
# theta: [-2.48218772]
# np.cos(theta)[0]: -0.7903569357747766
# -np.sin(theta)*delta_t*v[k-1]: 0.41590030800974237
# theta: [-2.55121977]
# np.cos(theta)[0]: -0.8307331625982333
# -np.sin(theta)*delta_t*v[k-1]: 0.4466770511246673
# theta: [-2.56237226]
# np.cos(theta)[0]: -0.8368896378138847
# -np.sin(theta)*delta_t*v[k-1]: 0.2977779631608335
# theta: [-2.56327727]
# np.cos(theta)[0]: -0.83738467434352
# -np.sin(theta)*delta_t*v[k-1]: 0.33187470575527905
# theta: [-2.52664013]
# np.cos(theta)[0]: -0.8168008367578465
# -np.sin(theta)*delta_t*v[k-1]: 0.41271259895933404
# theta: [-2.48270232]
# np.cos(theta)[0]: -0.790672097139719
# -np.sin(theta)*delta_t*v[k-1]: 0.45068817204216327
# theta: [-2.44313604]
# np.cos(theta)[0]: -0.7658355531206069
# -np.sin(theta)*delta_t*v[k-1]: 0.48757361735656785
# theta: [-2.38580786]
# np.cos(theta)[0]: -0.7277335059541767
# -np.sin(theta)*delta_t*v[k-1]: 0.4831723083859922
# theta: [-2.35017256]
# np.cos(theta)[0]: -0.7028358391533756
# -np.sin(theta)*delta_t*v[k-1]: 0.5209035131349754
# theta: [-2.41239074]
# np.cos(theta)[0]: -0.7457063871139497
# -np.sin(theta)*delta_t*v[k-1]: 0.49040815373329255
# theta: [-2.36120023]
# np.cos(theta)[0]: -0.7106374990233083
# -np.sin(theta)*delta_t*v[k-1]: 0.5912991897752554
# theta: [-2.42497925]
# np.cos(theta)[0]: -0.7540344836181468
# -np.sin(theta)*delta_t*v[k-1]: 0.45487777678454117
# theta: [-2.45821372]
# np.cos(theta)[0]: -0.7754436321068338
# -np.sin(theta)*delta_t*v[k-1]: 0.5704604511646097
# theta: [-2.41818158]
# np.cos(theta)[0]: -0.7495521503233485
# -np.sin(theta)*delta_t*v[k-1]: 0.48205691576980286
# theta: [-2.44554307]
# np.cos(theta)[0]: -0.7673811419060758
# -np.sin(theta)*delta_t*v[k-1]: 0.4658208415891592
# theta: [-2.45709709]
# np.cos(theta)[0]: -0.7747380896178229
# -np.sin(theta)*delta_t*v[k-1]: 0.5467056503871183
# theta: [-2.4599532]
# np.cos(theta)[0]: -0.7765407983002021
# -np.sin(theta)*delta_t*v[k-1]: 0.50965359936488
# theta: [-2.41458712]
# np.cos(theta)[0]: -0.7471679803850828
# -np.sin(theta)*delta_t*v[k-1]: 0.5814656696698057
# theta: [-2.45236008]
# np.cos(theta)[0]: -0.7717342829140549
# -np.sin(theta)*delta_t*v[k-1]: 0.5481643185824098
# theta: [-2.35688622]
# np.cos(theta)[0]: -0.7075957367636433
# -np.sin(theta)*delta_t*v[k-1]: 0.61812091723467
# theta: [-2.37388059]
# np.cos(theta)[0]: -0.7195015009006924
# -np.sin(theta)*delta_t*v[k-1]: 0.5318163502143048
# theta: [-2.34707005]
# np.cos(theta)[0]: -0.700625483625257
# -np.sin(theta)*delta_t*v[k-1]: 0.5504309883201102
# theta: [-2.40446521]
# np.cos(theta)[0]: -0.7404024408034868
# -np.sin(theta)*delta_t*v[k-1]: 0.5581687029084097
# theta: [-2.36644864]
# np.cos(theta)[0]: -0.71432025755423
# -np.sin(theta)*delta_t*v[k-1]: 0.5563381209331741
# theta: [-2.40002801]
# np.cos(theta)[0]: -0.7374126333367989
# -np.sin(theta)*delta_t*v[k-1]: 0.5884343456791671
# theta: [-2.3240109]
# np.cos(theta)[0]: -0.6839873032524851
# -np.sin(theta)*delta_t*v[k-1]: 0.6303910049333393
# theta: [-2.35088895]
# np.cos(theta)[0]: -0.7033452664285316
# -np.sin(theta)*delta_t*v[k-1]: 0.6784252772025866
# theta: [-2.34190569]
# np.cos(theta)[0]: -0.6969312341259282
# -np.sin(theta)*delta_t*v[k-1]: 0.5286766720999034
# theta: [-2.34691572]
# np.cos(theta)[0]: -0.7005153536507945
# -np.sin(theta)*delta_t*v[k-1]: 0.7155647492787907
# theta: [-2.30580591]
# np.cos(theta)[0]: -0.6705942657072973
# -np.sin(theta)*delta_t*v[k-1]: 0.6438587200672473
# theta: [-2.38602383]
# np.cos(theta)[0]: -0.7278816151485454
# -np.sin(theta)*delta_t*v[k-1]: 0.5764944386423179
# theta: [-2.39499159]
# np.cos(theta)[0]: -0.7340014858775424
# -np.sin(theta)*delta_t*v[k-1]: 0.6027316881265433
# theta: [-2.38606427]
# np.cos(theta)[0]: -0.7279093475116583
# -np.sin(theta)*delta_t*v[k-1]: 0.6098724676017024
# theta: [-2.35093782]
# np.cos(theta)[0]: -0.7033800014905546
# -np.sin(theta)*delta_t*v[k-1]: 0.6175032518810473
# theta: [-2.28229316]
# np.cos(theta)[0]: -0.6529681798810922
# -np.sin(theta)*delta_t*v[k-1]: 0.6696013951608571
# theta: [-2.37353527]
# np.cos(theta)[0]: -0.7192616366833094
# -np.sin(theta)*delta_t*v[k-1]: 0.659361735149201
# theta: [-2.40865302]
# np.cos(theta)[0]: -0.7432108362706107
# -np.sin(theta)*delta_t*v[k-1]: 0.4956271753930141
# theta: [-2.32700545]
# np.cos(theta)[0]: -0.6861687362098107
# -np.sin(theta)*delta_t*v[k-1]: 0.7281306658165798
# theta: [-2.35053719]
# np.cos(theta)[0]: -0.703095170368455
# -np.sin(theta)*delta_t*v[k-1]: 0.6138612605691859
# theta: [-2.4230854]
# np.cos(theta)[0]: -0.7527891872702663
# -np.sin(theta)*delta_t*v[k-1]: 0.529499277777394
# theta: [-2.39673653]
# np.cos(theta)[0]: -0.735185440404644
# -np.sin(theta)*delta_t*v[k-1]: 0.5672250666513149
# theta: [-2.35928958]
# np.cos(theta)[0]: -0.7092919512318948
# -np.sin(theta)*delta_t*v[k-1]: 0.6179438620126888
# theta: [-2.33725148]
# np.cos(theta)[0]: -0.6935859840438375
# -np.sin(theta)*delta_t*v[k-1]: 0.6455594576152393
# theta: [-2.37172731]
# np.cos(theta)[0]: -0.7180044048579812
# -np.sin(theta)*delta_t*v[k-1]: 0.6019405641082288
# theta: [-2.3995977]
# np.cos(theta)[0]: -0.7371219189083708
# -np.sin(theta)*delta_t*v[k-1]: 0.55978095565781
# theta: [-2.35060457]
# np.cos(theta)[0]: -0.7031430864517962
# -np.sin(theta)*delta_t*v[k-1]: 0.6382454211876999
# theta: [-2.39384935]
# np.cos(theta)[0]: -0.7332252551365858
# -np.sin(theta)*delta_t*v[k-1]: 0.5350702951681521
# theta: [-2.33182373]
# np.cos(theta)[0]: -0.6896657777896912
# -np.sin(theta)*delta_t*v[k-1]: 0.7964679496081872
# theta: [-2.41274262]
# np.cos(theta)[0]: -0.7459407898492411
# -np.sin(theta)*delta_t*v[k-1]: 0.6317838522196412
# theta: [-2.33683694]
# np.cos(theta)[0]: -0.6932873039630767
# -np.sin(theta)*delta_t*v[k-1]: 0.5686932306274941
# theta: [-2.4063589]
# np.cos(theta)[0]: -0.7416739833380535
# -np.sin(theta)*delta_t*v[k-1]: 0.6524485298071597
# theta: [-2.47453147]
# np.cos(theta)[0]: -0.7856432425025668
# -np.sin(theta)*delta_t*v[k-1]: 0.5840953200743334
# theta: [-2.45913946]
# np.cos(theta)[0]: -0.7760278303096404
# -np.sin(theta)*delta_t*v[k-1]: 0.6087069117391154
# theta: [-2.39048508]
# np.cos(theta)[0]: -0.7309334518611054
# -np.sin(theta)*delta_t*v[k-1]: 0.6163837873885424
# theta: [-2.37234291]
# np.cos(theta)[0]: -0.7184327490786718
# -np.sin(theta)*delta_t*v[k-1]: 0.5573735191171989
# theta: [-2.30179938]
# np.cos(theta)[0]: -0.667616752600106
# -np.sin(theta)*delta_t*v[k-1]: 0.6934946442262817
# theta: [-2.3628178]
# np.cos(theta)[0]: -0.7117746237210364
# -np.sin(theta)*delta_t*v[k-1]: 0.5495768573742268
# theta: [-2.33446288]
# np.cos(theta)[0]: -0.6915744593383338
# -np.sin(theta)*delta_t*v[k-1]: 0.5973044027368193
# theta: [-2.37252486]
# np.cos(theta)[0]: -0.718559301144986
# -np.sin(theta)*delta_t*v[k-1]: 0.5431885917439524
# theta: [-2.42758615]
# np.cos(theta)[0]: -0.7557442221098993
# -np.sin(theta)*delta_t*v[k-1]: 0.5183442887138306
# theta: [-2.46784474]
# np.cos(theta)[0]: -0.7814887646659583
# -np.sin(theta)*delta_t*v[k-1]: 0.538188915131802
# theta: [-2.42113281]
# np.cos(theta)[0]: -0.7515024364334991
# -np.sin(theta)*delta_t*v[k-1]: 0.6054361230438232
# theta: [-2.36555027]
# np.cos(theta)[0]: -0.713691274488246
# -np.sin(theta)*delta_t*v[k-1]: 0.5286321928274477
# theta: [-2.41512924]
# np.cos(theta)[0]: -0.7475281770379646
# -np.sin(theta)*delta_t*v[k-1]: 0.5356191415615945
# theta: [-2.44522395]
# np.cos(theta)[0]: -0.7671764828549202
# -np.sin(theta)*delta_t*v[k-1]: 0.47834944756894593
# theta: [-2.3848285]
# np.cos(theta)[0]: -0.7270614559710944
# -np.sin(theta)*delta_t*v[k-1]: 0.546695166210951
# theta: [-2.47962852]
# np.cos(theta)[0]: -0.7887864649412613
# -np.sin(theta)*delta_t*v[k-1]: 0.5073994153944821
# theta: [-2.4948649]
# np.cos(theta)[0]: -0.7980598543603119
# -np.sin(theta)*delta_t*v[k-1]: 0.4569007712828463
# theta: [-2.49747974]
# np.cos(theta)[0]: -0.799632769052301
# -np.sin(theta)*delta_t*v[k-1]: 0.4590674094990697
# theta: [-2.55454631]
# np.cos(theta)[0]: -0.8325803517552396
# -np.sin(theta)*delta_t*v[k-1]: 0.4678961635239677
# theta: [-2.5158328]
# np.cos(theta)[0]: -0.8105182966158085
# -np.sin(theta)*delta_t*v[k-1]: 0.3815994609263055
# theta: [-2.5572245]
# np.cos(theta)[0]: -0.8340608249808005
# -np.sin(theta)*delta_t*v[k-1]: 0.3573110091927255
# theta: [-2.56391807]
# np.cos(theta)[0]: -0.8377347689155663
# -np.sin(theta)*delta_t*v[k-1]: 0.33407193564228077
# theta: [-2.56597493]
# np.cos(theta)[0]: -0.838856201585269
# -np.sin(theta)*delta_t*v[k-1]: 0.4114918972576707
# theta: [-2.48072959]
# np.cos(theta)[0]: -0.7894627794331004
# -np.sin(theta)*delta_t*v[k-1]: 0.45600425292352986
# theta: [-2.58537414]
# np.cos(theta)[0]: -0.8492577243112669
# -np.sin(theta)*delta_t*v[k-1]: 0.3568506853722218
# theta: [1.87491473]
# np.cos(theta)[0]: -0.2994521520604707
# -np.sin(theta)*delta_t*v[k-1]: -0.6021787574779525
# theta: [1.1488753]
# np.cos(theta)[0]: 0.4095137649550429
# -np.sin(theta)*delta_t*v[k-1]: -0.6569555398629191
# theta: [0.89874022]
# np.cos(theta)[0]: 0.6225962974840509
# -np.sin(theta)*delta_t*v[k-1]: -0.5416312855706135
# theta: [0.7093452]
# np.cos(theta)[0]: 0.7587885321345309
# -np.sin(theta)*delta_t*v[k-1]: -0.4330928682215094
# theta: [0.64695608]
# np.cos(theta)[0]: 0.7979222457248055
# -np.sin(theta)*delta_t*v[k-1]: -0.3638572796692403
# theta: [0.62874775]
# np.cos(theta)[0]: 0.8087646333083897
# -np.sin(theta)*delta_t*v[k-1]: -0.40446166752970486
# theta: [1.41500991]
# np.cos(theta)[0]: 0.15515704321988252
# -np.sin(theta)*delta_t*v[k-1]: -0.4903669080868625
# theta: [0.90693723]
# np.cos(theta)[0]: 0.6161609366428501
# -np.sin(theta)*delta_t*v[k-1]: -0.47896275043036746
# theta: [0.74552602]
# np.cos(theta)[0]: 0.7347311740571246
# -np.sin(theta)*delta_t*v[k-1]: -0.36477168920318004
# theta: [1.44094556]
# np.cos(theta)[0]: 0.12948616863293105
# -np.sin(theta)*delta_t*v[k-1]: -0.5653886794300557
# theta: [1.83295051]
# np.cos(theta)[0]: -0.2591617388793073
# -np.sin(theta)*delta_t*v[k-1]: -0.5799826918138986
# theta: [1.98193423]
# np.cos(theta)[0]: -0.3996526638909346
# -np.sin(theta)*delta_t*v[k-1]: -0.5224803344530418
# theta: [2.05187526]
# np.cos(theta)[0]: -0.46273591121448016
# -np.sin(theta)*delta_t*v[k-1]: -0.49978498340898025
# theta: [2.05686482]
# np.cos(theta)[0]: -0.4671533659666845
# -np.sin(theta)*delta_t*v[k-1]: -0.45936630841335985
# theta: [2.03968527]
# np.cos(theta)[0]: -0.4518954215418281
# -np.sin(theta)*delta_t*v[k-1]: -0.4885207485216941
# theta: [2.13097286]
# np.cos(theta)[0]: -0.5313357609152289
# -np.sin(theta)*delta_t*v[k-1]: -0.41799579210700283
# theta: [2.08313314]
# np.cos(theta)[0]: -0.4902153509664631
# -np.sin(theta)*delta_t*v[k-1]: -0.3633537510479573
# theta: [1.96463442]
# np.cos(theta)[0]: -0.38373548909151256
# -np.sin(theta)*delta_t*v[k-1]: -0.41948299854571836
# theta: [1.9907141]
# np.cos(theta)[0]: -0.40768537491097645
# -np.sin(theta)*delta_t*v[k-1]: -0.3608953381678417
# theta: [1.95186015]
# np.cos(theta)[0]: -0.3719081961718565
# -np.sin(theta)*delta_t*v[k-1]: -0.4945771021775967
# theta: [2.334807]
# np.cos(theta)[0]: -0.6918229745792349
# -np.sin(theta)*delta_t*v[k-1]: -0.31552054361855963
# theta: [2.48459126]
# np.cos(theta)[0]: -0.7918271733678622
# -np.sin(theta)*delta_t*v[k-1]: -0.21178104840028744
# theta: [2.4295717]
# np.cos(theta)[0]: -0.7570430033053578
# -np.sin(theta)*delta_t*v[k-1]: -0.26404139283738776
# theta: [2.44284728]
# np.cos(theta)[0]: -0.7656498390267861
# -np.sin(theta)*delta_t*v[k-1]: -0.3316433623940808
# theta: [2.45083508]
# np.cos(theta)[0]: -0.7707635679117337
# -np.sin(theta)*delta_t*v[k-1]: -0.34630537069042927
# theta: [2.44371342]
# np.cos(theta)[0]: -0.7662066999731508
# -np.sin(theta)*delta_t*v[k-1]: -0.2249172599329681
# theta: [2.43369614]
# np.cos(theta)[0]: -0.7597313186244526
# -np.sin(theta)*delta_t*v[k-1]: -0.21367036760574742
# theta: [2.82156937]
# np.cos(theta)[0]: -0.9492280938321656
# -np.sin(theta)*delta_t*v[k-1]: -0.13603709609639666
# theta: [2.88626352]
# np.cos(theta)[0]: -0.9675802203926137
# -np.sin(theta)*delta_t*v[k-1]: -0.08781142359906854
# theta: [2.93454979]
# np.cos(theta)[0]: -0.978643082064336
# -np.sin(theta)*delta_t*v[k-1]: -0.09563701829691833
# theta: [2.97238609]
# np.cos(theta)[0]: -0.9857186918814791
# -np.sin(theta)*delta_t*v[k-1]: -0.07691537106951553
# theta: [2.90849914]
# np.cos(theta)[0]: -0.9729564851093196
# -np.sin(theta)*delta_t*v[k-1]: -0.11051553967192718
# theta: [2.81539009]
# np.cos(theta)[0]: -0.9472660507753811
# -np.sin(theta)*delta_t*v[k-1]: -0.1679162955039589
# theta: [2.76155133]
# np.cos(theta)[0]: -0.9286493068506865
# -np.sin(theta)*delta_t*v[k-1]: -0.11290432847977158
# theta: [2.80712198]
# np.cos(theta)[0]: -0.9445842022734748
# -np.sin(theta)*delta_t*v[k-1]: -0.1250765495172306
# theta: [2.75882752]
# np.cos(theta)[0]: -0.9276354405627649
# -np.sin(theta)*delta_t*v[k-1]: -0.2031062594306203
# theta: [2.68775322]
# np.cos(theta)[0]: -0.8987704464984853
# -np.sin(theta)*delta_t*v[k-1]: -0.23047207875626305
# theta: [2.64081718]
# np.cos(theta)[0]: -0.8772105155552836
# -np.sin(theta)*delta_t*v[k-1]: -0.17725840087693864
# theta: [2.62965608]
# np.cos(theta)[0]: -0.8717974787877311
# -np.sin(theta)*delta_t*v[k-1]: -0.2509303727056613
# theta: [2.53836824]
# np.cos(theta)[0]: -0.8235106845591474
# -np.sin(theta)*delta_t*v[k-1]: -0.23120010005014446
# theta: [2.51374835]
# np.cos(theta)[0]: -0.809295644601456
# -np.sin(theta)*delta_t*v[k-1]: -0.34247992857540394
# theta: [2.46745705]
# np.cos(theta)[0]: -0.7812468157404041
# -np.sin(theta)*delta_t*v[k-1]: -0.26202861985971315
# theta: [2.4572005]
# np.cos(theta)[0]: -0.7748034745497141
# -np.sin(theta)*delta_t*v[k-1]: -0.31909401415770133
# theta: [2.41817765]
# np.cos(theta)[0]: -0.7495495495253968
# -np.sin(theta)*delta_t*v[k-1]: -0.27246738915471463
# theta: [2.39249798]
# np.cos(theta)[0]: -0.7323056758009399
# -np.sin(theta)*delta_t*v[k-1]: -0.30832704427451096
# theta: [2.37708216]
# np.cos(theta)[0]: -0.721721272942427
# -np.sin(theta)*delta_t*v[k-1]: -0.35139030286273654
# theta: [2.31000509]
# np.cos(theta)[0]: -0.6737034004519428
# -np.sin(theta)*delta_t*v[k-1]: -0.3468281194430425
# theta: [2.21610707]
# np.cos(theta)[0]: -0.6014467207624021
# -np.sin(theta)*delta_t*v[k-1]: -0.26857403710525524
# C:\Users\User\AppData\Local\Temp\ipykernel_13952\3332860911.py:18: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   H_k[0,0] = -d_x/r
# C:\Users\User\AppData\Local\Temp\ipykernel_13952\3332860911.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   H_k[0,1] = -d_y/r
# C:\Users\User\AppData\Local\Temp\ipykernel_13952\3332860911.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   H_k[0,2] = d*(d_x*np.sin(theta_k) - d_y*np.cos(theta_k))/r
# C:\Users\User\AppData\Local\Temp\ipykernel_13952\3332860911.py:21: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   H_k[1,0] = d_y/r**2
# C:\Users\User\AppData\Local\Temp\ipykernel_13952\3332860911.py:22: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   H_k[1,1] = -d_x/r**2
# C:\Users\User\AppData\Local\Temp\ipykernel_13952\3332860911.py:23: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   H_k[1,2] = -1-d*(d_y*np.sin(theta_k) + d_x*np.cos(theta_k))/r**2
# C:\Users\User\AppData\Local\Temp\ipykernel_13952\2063914006.py:50: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_est[k, 0] = x_check[0]
# C:\Users\User\AppData\Local\Temp\ipykernel_13952\2063914006.py:51: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_est[k, 1] = x_check[1]
# C:\Users\User\AppData\Local\Temp\ipykernel_13952\2063914006.py:52: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_est[k, 2] = x_check[2]
# theta: [2.27021645]
# np.cos(theta)[0]: -0.6437740622248266
# -np.sin(theta)*delta_t*v[k-1]: -0.4389731412731253
# theta: [2.24016156]
# np.cos(theta)[0]: -0.6204883212667981
# -np.sin(theta)*delta_t*v[k-1]: -0.44823707439377675
# theta: [2.14233987]
# np.cos(theta)[0]: -0.5409309162208924
# -np.sin(theta)*delta_t*v[k-1]: -0.3577141688385962
# theta: [2.14006185]
# np.cos(theta)[0]: -0.5390135436604206
# -np.sin(theta)*delta_t*v[k-1]: -0.4005498564253142
# theta: [2.16810133]
# np.cos(theta)[0]: -0.5624161462150663
# -np.sin(theta)*delta_t*v[k-1]: -0.39601641133117826
# theta: [2.11369425]
# np.cos(theta)[0]: -0.5166194031636241
# -np.sin(theta)*delta_t*v[k-1]: -0.4122890440197603
# theta: [2.07519639]
# np.cos(theta)[0]: -0.4832823070372474
# -np.sin(theta)*delta_t*v[k-1]: -0.3264243171657643
# theta: [2.05809511]
# np.cos(theta)[0]: -0.4682408004196301
# -np.sin(theta)*delta_t*v[k-1]: -0.5579674130652345
# theta: [2.08031428]
# np.cos(theta)[0]: -0.48775648403158317
# -np.sin(theta)*delta_t*v[k-1]: -0.5111659830755827
# theta: [2.06655168]
# np.cos(theta)[0]: -0.4756962064388271
# -np.sin(theta)*delta_t*v[k-1]: -0.46329731751087694
# theta: [2.00145033]
# np.cos(theta)[0]: -0.41746518078673817
# -np.sin(theta)*delta_t*v[k-1]: -0.40785093707727105
# theta: [1.98541912]
# np.cos(theta)[0]: -0.40284471382244297
# -np.sin(theta)*delta_t*v[k-1]: -0.5479594227698152
# theta: [1.94103145]
# np.cos(theta)[0]: -0.361834632579044
# -np.sin(theta)*delta_t*v[k-1]: -0.470918098376851
# theta: [1.84373029]
# np.cos(theta)[0]: -0.2695579509471878
# -np.sin(theta)*delta_t*v[k-1]: -0.48734144286150644
# theta: [1.81933951]
# np.cos(theta)[0]: -0.2459921687161712
# -np.sin(theta)*delta_t*v[k-1]: -0.4770582812920804
# theta: [1.90419914]
# np.cos(theta)[0]: -0.3272603524865796
# -np.sin(theta)*delta_t*v[k-1]: -0.5085078925813189
# theta: [1.90044899]
# np.cos(theta)[0]: -0.32371441672552037
# -np.sin(theta)*delta_t*v[k-1]: -0.5476351277370355
# theta: [1.87827941]
# np.cos(theta)[0]: -0.30266073005788696
# -np.sin(theta)*delta_t*v[k-1]: -0.4673008961785917
# theta: [1.90823688]
# np.cos(theta)[0]: -0.3310730737983452
# -np.sin(theta)*delta_t*v[k-1]: -0.5835197532902041
# theta: [1.86639653]
# np.cos(theta)[0]: -0.2913140755409539
# -np.sin(theta)*delta_t*v[k-1]: -0.49022379304434743
# theta: [1.75500311]
# np.cos(theta)[0]: -0.18316679285483498
# -np.sin(theta)*delta_t*v[k-1]: -0.5008998677675075
# theta: [1.79050691]
# np.cos(theta)[0]: -0.2179471705660851
# -np.sin(theta)*delta_t*v[k-1]: -0.6387037322606584
# theta: [1.81621091]
# np.cos(theta)[0]: -0.24295850512301034
# -np.sin(theta)*delta_t*v[k-1]: -0.43439725314246425
# theta: [1.77178699]
# np.cos(theta)[0]: -0.19964015381367226
# -np.sin(theta)*delta_t*v[k-1]: -0.6635271315293652
# theta: [1.76595282]
# np.cos(theta)[0]: -0.1939200588526217
# -np.sin(theta)*delta_t*v[k-1]: -0.5869474315126171
# theta: [1.74024127]
# np.cos(theta)[0]: -0.16863526795433365
# -np.sin(theta)*delta_t*v[k-1]: -0.6416882424720989
# theta: [1.73666316]
# np.cos(theta)[0]: -0.1651073281394875
# -np.sin(theta)*delta_t*v[k-1]: -0.5286429594022823
# theta: [1.73258056]
# np.cos(theta)[0]: -0.1610794001921749
# -np.sin(theta)*delta_t*v[k-1]: -0.5665308043454291
# theta: [1.69019889]
# np.cos(theta)[0]: -0.11911905042817854
# -np.sin(theta)*delta_t*v[k-1]: -0.746468708302038
# theta: [1.69440705]
# np.cos(theta)[0]: -0.1232961746714423
# -np.sin(theta)*delta_t*v[k-1]: -0.4252657305188305
# theta: [1.65064629]
# np.cos(theta)[0]: -0.07976513567954414
# -np.sin(theta)*delta_t*v[k-1]: -0.7357273855015488
# theta: [1.64772063]
# np.cos(theta)[0]: -0.07684845795990021
# -np.sin(theta)*delta_t*v[k-1]: -0.6360992414043971
# theta: [1.65046722]
# np.cos(theta)[0]: -0.07958663868232048
# -np.sin(theta)*delta_t*v[k-1]: -0.5857836857605885
# theta: [1.61032304]
# np.cos(theta)[0]: -0.039516420819424414
# -np.sin(theta)*delta_t*v[k-1]: -0.694441593899417
# theta: [1.57928832]
# np.cos(theta)[0]: -0.008491893252016254
# -np.sin(theta)*delta_t*v[k-1]: -0.5739085118448353
# theta: [1.63035218]
# np.cos(theta)[0]: -0.05952065007101848
# -np.sin(theta)*delta_t*v[k-1]: -0.5663583699941092
# theta: [1.64103968]
# np.cos(theta)[0]: -0.07018560212948086
# -np.sin(theta)*delta_t*v[k-1]: -0.6876127185666945
# theta: [1.58614402]
# np.cos(theta)[0]: -0.01534709123558525
# -np.sin(theta)*delta_t*v[k-1]: -0.5737498727560894
# theta: [1.54387159]
# np.cos(theta)[0]: 0.026921480821521036
# -np.sin(theta)*delta_t*v[k-1]: -0.5819600144079735
# theta: [1.47134198]
# np.cos(theta)[0]: 0.09929047347104969
# -np.sin(theta)*delta_t*v[k-1]: -0.6437631393219585
# theta: [1.4783114]
# np.cos(theta)[0]: 0.09235314242337214
# -np.sin(theta)*delta_t*v[k-1]: -0.722305392251766
# theta: [1.51973323]
# np.cos(theta)[0]: 0.05104091125203304
# -np.sin(theta)*delta_t*v[k-1]: -0.7156584664476834
# theta: [1.56013589]
# np.cos(theta)[0]: 0.010660232833361398
# -np.sin(theta)*delta_t*v[k-1]: -0.5997815559654089
# theta: [1.44091033]
# np.cos(theta)[0]: 0.12952110376947842
# -np.sin(theta)*delta_t*v[k-1]: -0.6349808990165271
# theta: [1.47720723]
# np.cos(theta)[0]: 0.09345253610803475
# -np.sin(theta)*delta_t*v[k-1]: -0.6038000878482537
# theta: [1.44617327]
# np.cos(theta)[0]: 0.12430072001008946
# -np.sin(theta)*delta_t*v[k-1]: -0.615731006173232
# theta: [1.52197179]
# np.cos(theta)[0]: 0.04880514182027945
# -np.sin(theta)*delta_t*v[k-1]: -0.655528286319128
# theta: [1.45564823]
# np.cos(theta)[0]: 0.11489380328585451
# -np.sin(theta)*delta_t*v[k-1]: -0.6079440157599858
# theta: [1.44536083]
# np.cos(theta)[0]: 0.12510681841489363
# -np.sin(theta)*delta_t*v[k-1]: -0.5852649548163084
# theta: [1.32062717]
# np.cos(theta)[0]: 0.24756785701553652
# -np.sin(theta)*delta_t*v[k-1]: -0.7041462512501885
# theta: [1.41706532]
# np.cos(theta)[0]: 0.15312619235038724
# -np.sin(theta)*delta_t*v[k-1]: -0.6625758680884798
# theta: [1.4449635]
# np.cos(theta)[0]: 0.12550102027225807
# -np.sin(theta)*delta_t*v[k-1]: -0.5762722646187376
# theta: [1.41946427]
# np.cos(theta)[0]: 0.1507551008863846
# -np.sin(theta)*delta_t*v[k-1]: -0.6281969122671739
# theta: [1.35089257]
# np.cos(theta)[0]: 0.2181356943942138
# -np.sin(theta)*delta_t*v[k-1]: -0.532036765429157
# theta: [1.3666544]
# np.cos(theta)[0]: 0.20272697826525093
# -np.sin(theta)*delta_t*v[k-1]: -0.6845469908959759
# theta: [1.31232238]
# np.cos(theta)[0]: 0.25560548961043067
# -np.sin(theta)*delta_t*v[k-1]: -0.5472734186082641
# theta: [1.35126182]
# np.cos(theta)[0]: 0.2177753255392591
# -np.sin(theta)*delta_t*v[k-1]: -0.6299508061178525
# theta: [1.30468762]
# np.cos(theta)[0]: 0.26297910882291275
# -np.sin(theta)*delta_t*v[k-1]: -0.6459679264094483
# theta: [1.32515945]
# np.cos(theta)[0]: 0.2431741366582636
# -np.sin(theta)*delta_t*v[k-1]: -0.6746002197902774
# theta: [1.34280423]
# np.cos(theta)[0]: 0.22602203633741902
# -np.sin(theta)*delta_t*v[k-1]: -0.5032887670037707
# theta: [1.28002326]
# np.cos(theta)[0]: 0.28669292544318237
# -np.sin(theta)*delta_t*v[k-1]: -0.51789885271211
# theta: [1.25726408]
# np.cos(theta)[0]: 0.3084206017449456
# -np.sin(theta)*delta_t*v[k-1]: -0.5728840662301915
# theta: [1.27071589]
# np.cos(theta)[0]: 0.29559704524077945
# -np.sin(theta)*delta_t*v[k-1]: -0.6017073139562022
# theta: [1.27289248]
# np.cos(theta)[0]: 0.29351702364946725
# -np.sin(theta)*delta_t*v[k-1]: -0.47255290370046515
# theta: [1.16162005]
# np.cos(theta)[0]: 0.3978537423295333
# -np.sin(theta)*delta_t*v[k-1]: -0.5813563177790572
# theta: [1.14577057]
# np.cos(theta)[0]: 0.4123442450069392
# -np.sin(theta)*delta_t*v[k-1]: -0.46313118381374224
# theta: [1.12289795]
# np.cos(theta)[0]: 0.4330721712494945
# -np.sin(theta)*delta_t*v[k-1]: -0.504949084286531
# theta: [1.08505932]
# np.cos(theta)[0]: 0.4668602417737007
# -np.sin(theta)*delta_t*v[k-1]: -0.5016918575419536
# theta: [1.08702689]
# np.cos(theta)[0]: 0.46511935598450743
# -np.sin(theta)*delta_t*v[k-1]: -0.44527055663860954
# theta: [1.13157663]
# np.cos(theta)[0]: 0.4252333545178162
# -np.sin(theta)*delta_t*v[k-1]: -0.4828346027259635
# theta: [1.06846822]
# np.cos(theta)[0]: 0.4814673420417205
# -np.sin(theta)*delta_t*v[k-1]: -0.4294449236515153
# theta: [0.96172643]
# np.cos(theta)[0]: 0.5721048578780253
# -np.sin(theta)*delta_t*v[k-1]: -0.4158584759150853
# theta: [1.00613742]
# np.cos(theta)[0]: 0.5351276978095574
# -np.sin(theta)*delta_t*v[k-1]: -0.39623500264152567
# theta: [0.8860443]
# np.cos(theta)[0]: 0.6324809553660113
# -np.sin(theta)*delta_t*v[k-1]: -0.3736124410456536
# theta: [0.91313267]
# np.cos(theta)[0]: 0.6112694886935285
# -np.sin(theta)*delta_t*v[k-1]: -0.3935538806622785
# theta: [0.95144339]
# np.cos(theta)[0]: 0.5805084074464623
# -np.sin(theta)*delta_t*v[k-1]: -0.42397745076634735
# theta: [0.93225342]
# np.cos(theta)[0]: 0.5960260810105653
# -np.sin(theta)*delta_t*v[k-1]: -0.42967043792921017
# theta: [0.90042783]
# np.cos(theta)[0]: 0.6212747829149818
# -np.sin(theta)*delta_t*v[k-1]: -0.3749508322256148
# theta: [0.90906919]
# np.cos(theta)[0]: 0.6144803642484598
# -np.sin(theta)*delta_t*v[k-1]: -0.2762444044582176
# theta: [0.80964213]
# np.cos(theta)[0]: 0.6897575917008938
# -np.sin(theta)*delta_t*v[k-1]: -0.3194016362281531
# theta: [0.74406834]
# np.cos(theta)[0]: 0.7357192250193458
# -np.sin(theta)*delta_t*v[k-1]: -0.2694173252437518
# theta: [0.74649119]
# np.cos(theta)[0]: 0.7340761040699629
# -np.sin(theta)*delta_t*v[k-1]: -0.25145835126147636
# theta: [0.69861564]
# np.cos(theta)[0]: 0.7657332823342571
# -np.sin(theta)*delta_t*v[k-1]: -0.31799821197221867
# theta: [0.6824363]
# np.cos(theta)[0]: 0.7760384872529423
# -np.sin(theta)*delta_t*v[k-1]: -0.34645707120733865
# theta: [0.60270407]
# np.cos(theta)[0]: 0.8238057686474021
# -np.sin(theta)*delta_t*v[k-1]: -0.1725901640748994
# theta: [0.67920221]
# np.cos(theta)[0]: 0.7780741145225506
# -np.sin(theta)*delta_t*v[k-1]: -0.31982829886334735
# theta: [0.60574476]
# np.cos(theta)[0]: 0.8220782797235976
# -np.sin(theta)*delta_t*v[k-1]: -0.2800774558736221
# theta: [0.5175232]
# np.cos(theta)[0]: 0.8690471894662687
# -np.sin(theta)*delta_t*v[k-1]: -0.2767493819067452
# theta: [0.50655062]
# np.cos(theta)[0]: 0.874423222407679
# -np.sin(theta)*delta_t*v[k-1]: -0.19545462056695542
# theta: [0.47026434]
# np.cos(theta)[0]: 0.8914485408100783
# -np.sin(theta)*delta_t*v[k-1]: -0.23798640264488763
# theta: [0.36543826]
# np.cos(theta)[0]: 0.9339672358092885
# -np.sin(theta)*delta_t*v[k-1]: -0.1201963660643693
# theta: [0.38161956]
# np.cos(theta)[0]: 0.9280626888946831
# -np.sin(theta)*delta_t*v[k-1]: -0.19070775257599815
# theta: [0.29207965]
# np.cos(theta)[0]: 0.9576471245025807
# -np.sin(theta)*delta_t*v[k-1]: -0.13048082182635
# theta: [0.22984166]
# np.cos(theta)[0]: 0.97370248040301
# -np.sin(theta)*delta_t*v[k-1]: -0.06751575406720564
# theta: [0.1620479]
# np.cos(theta)[0]: 0.9868989464826784
# -np.sin(theta)*delta_t*v[k-1]: -0.061992788732699984
# theta: [0.17574873]
# np.cos(theta)[0]: 0.9845959031143993
# -np.sin(theta)*delta_t*v[k-1]: -0.0644604741406538
# theta: [0.19016749]
# np.cos(theta)[0]: 0.9819725894797563
# -np.sin(theta)*delta_t*v[k-1]: -0.06541917356468668
# theta: [0.13995903]
# np.cos(theta)[0]: 0.990221712377897
# -np.sin(theta)*delta_t*v[k-1]: -0.050574573648328805
# theta: [0.04230198]
# np.cos(theta)[0]: 0.9991054044575937
# -np.sin(theta)*delta_t*v[k-1]: -0.019084143743757654
# theta: [0.0597371]
# np.cos(theta)[0]: 0.9982162701333873
# -np.sin(theta)*delta_t*v[k-1]: -0.024434874447714576
# theta: [0.0398761]
# np.cos(theta)[0]: 0.9992050536509108
# -np.sin(theta)*delta_t*v[k-1]: -0.020386330531226796
# theta: [-0.07447851]
# np.cos(theta)[0]: 0.9972277572510243
# -np.sin(theta)*delta_t*v[k-1]: 0.026099948504922553
# theta: [-0.12908041]
# np.cos(theta)[0]: 0.9916806850671227
# -np.sin(theta)*delta_t*v[k-1]: 0.05759368383756284
# theta: [-0.06675773]
# np.cos(theta)[0]: 0.9977725301572825
# -np.sin(theta)*delta_t*v[k-1]: 0.045794457597814565
# theta: [-0.16416223]
# np.cos(theta)[0]: 0.9865556144423481
# -np.sin(theta)*delta_t*v[k-1]: 0.06676953364845103
# theta: [-0.16293057]
# np.cos(theta)[0]: 0.9867561511087977
# -np.sin(theta)*delta_t*v[k-1]: 0.08068615645166775
# theta: [-0.64484497]
# np.cos(theta)[0]: 0.7991929638233687
# -np.sin(theta)*delta_t*v[k-1]: 0.293724541936921
# theta: [-0.43490214]
# np.cos(theta)[0]: 0.9069112775848168
# -np.sin(theta)*delta_t*v[k-1]: 0.20320470174714053
# theta: [-0.29586841]
# np.cos(theta)[0]: 0.9565492994019223
# -np.sin(theta)*delta_t*v[k-1]: 0.15622298249558286
# theta: [-0.30735801]
# np.cos(theta)[0]: 0.9531362080804128
# -np.sin(theta)*delta_t*v[k-1]: 0.12681508174124304
# theta: [-0.23381116]
# np.cos(theta)[0]: 0.9727904668337444
# -np.sin(theta)*delta_t*v[k-1]: 0.12305618820046921
# theta: [-0.33049591]
# np.cos(theta)[0]: 0.9458815302663742
# -np.sin(theta)*delta_t*v[k-1]: 0.1626443785072102
# theta: [-0.28349462]
# np.cos(theta)[0]: 0.9600838134830096
# -np.sin(theta)*delta_t*v[k-1]: 0.14462905101960413
# theta: [-0.38804723]
# np.cos(theta)[0]: 0.9256497180519474
# -np.sin(theta)*delta_t*v[k-1]: 0.18527079470476124
# theta: [-0.40939122]
# np.cos(theta)[0]: 0.917363316255836
# -np.sin(theta)*delta_t*v[k-1]: 0.22058837394227226
# theta: [-0.51660822]
# np.cos(theta)[0]: 0.869499493911492
# -np.sin(theta)*delta_t*v[k-1]: 0.32232236149079635
# theta: [-0.53476415]
# np.cos(theta)[0]: 0.860388853674909
# -np.sin(theta)*delta_t*v[k-1]: 0.2375353321859837
# theta: [-0.5377929]
# np.cos(theta)[0]: 0.8588413387691305
# -np.sin(theta)*delta_t*v[k-1]: 0.3116050497936571
# theta: [-0.46314143]
# np.cos(theta)[0]: 0.8946534443899204
# -np.sin(theta)*delta_t*v[k-1]: 0.22173886528837686
# theta: [-0.48697522]
# np.cos(theta)[0]: 0.883752359709613
# -np.sin(theta)*delta_t*v[k-1]: 0.31580163715598997
# theta: [-0.55909613]
# np.cos(theta)[0]: 0.8477348880952794
# -np.sin(theta)*delta_t*v[k-1]: 0.3669647212115017
# theta: [-0.51376308]
# np.cos(theta)[0]: 0.8709012805879371
# -np.sin(theta)*delta_t*v[k-1]: 0.27827164620700073
# theta: [-0.47942157]
# np.cos(theta)[0]: 0.887261883534561
# -np.sin(theta)*delta_t*v[k-1]: 0.28173404402415536
# theta: [-0.57763127]
# np.cos(theta)[0]: 0.8377584212966545
# -np.sin(theta)*delta_t*v[k-1]: 0.30332797278752816
# theta: [-0.56545243]
# np.cos(theta)[0]: 0.84434627468667
# -np.sin(theta)*delta_t*v[k-1]: 0.3421588043658895
# theta: [-0.57775026]
# np.cos(theta)[0]: 0.8376934423522847
# -np.sin(theta)*delta_t*v[k-1]: 0.34346676980603724
# theta: [-0.58987397]
# np.cos(theta)[0]: 0.8310107924081291
# -np.sin(theta)*delta_t*v[k-1]: 0.4067752218104836
# theta: [-0.56156979]
# np.cos(theta)[0]: 0.846420216132063
# -np.sin(theta)*delta_t*v[k-1]: 0.4047711610561645
# theta: [-0.58659186]
# np.cos(theta)[0]: 0.8328320031095114
# -np.sin(theta)*delta_t*v[k-1]: 0.3857881652738912
# theta: [-0.60192709]
# np.cos(theta)[0]: 0.8242459671708883
# -np.sin(theta)*delta_t*v[k-1]: 0.4061966557576781
# theta: [-0.63087868]
# np.cos(theta)[0]: 0.8075095273165014
# -np.sin(theta)*delta_t*v[k-1]: 0.4023766308346379
# theta: [-0.63537444]
# np.cos(theta)[0]: 0.8048495330777217
# -np.sin(theta)*delta_t*v[k-1]: 0.406091902641721
# theta: [-0.61957339]
# np.cos(theta)[0]: 0.8141262573077811
# -np.sin(theta)*delta_t*v[k-1]: 0.46707556256318356
# theta: [-0.65987437]
# np.cos(theta)[0]: 0.7900692482521742
# -np.sin(theta)*delta_t*v[k-1]: 0.43694187761259057
# theta: [-0.69910333]
# np.cos(theta)[0]: 0.7654195277738229
# -np.sin(theta)*delta_t*v[k-1]: 0.49875245533452484
# theta: [-0.65076244]
# np.cos(theta)[0]: 0.7956221474556545
# -np.sin(theta)*delta_t*v[k-1]: 0.46822108096180654
# theta: [-0.70950657]
# np.cos(theta)[0]: 0.7586834161556796
# -np.sin(theta)*delta_t*v[k-1]: 0.48167077462267405
# theta: [-0.6617009]
# np.cos(theta)[0]: 0.7889482370338691
# -np.sin(theta)*delta_t*v[k-1]: 0.4821619023840784
# theta: [-0.70477906]
# np.cos(theta)[0]: 0.7617547082559092
# -np.sin(theta)*delta_t*v[k-1]: 0.4186078518726252
# theta: [-0.66225662]
# np.cos(theta)[0]: 0.7886066479515732
# -np.sin(theta)*delta_t*v[k-1]: 0.4609782069120794
# theta: [-0.70605276]
# np.cos(theta)[0]: 0.7609289037339317
# -np.sin(theta)*delta_t*v[k-1]: 0.5192831760664577
# theta: [-0.74545695]
# np.cos(theta)[0]: 0.7347780261944372
# -np.sin(theta)*delta_t*v[k-1]: 0.549612076493458
# theta: [-0.77221594]
# np.cos(theta)[0]: 0.7163663168991369
# -np.sin(theta)*delta_t*v[k-1]: 0.5292704652222319
# theta: [-0.76587851]
# np.cos(theta)[0]: 0.7207736757052219
# -np.sin(theta)*delta_t*v[k-1]: 0.5606830731588179
# theta: [-0.73672398]
# np.cos(theta)[0]: 0.7406735725754032
# -np.sin(theta)*delta_t*v[k-1]: 0.5682956999639412
# theta: [-0.73197562]
# np.cos(theta)[0]: 0.7438554693270703
# -np.sin(theta)*delta_t*v[k-1]: 0.5332372886719258
# theta: [-0.82435294]
# np.cos(theta)[0]: 0.6790321203206018
# -np.sin(theta)*delta_t*v[k-1]: 0.6711891386393803
# theta: [-0.71470993]
# np.cos(theta)[0]: 0.755283385046249
# -np.sin(theta)*delta_t*v[k-1]: 0.5411812185739511
# theta: [-0.78605782]
# np.cos(theta)[0]: 0.7066401796600458
# -np.sin(theta)*delta_t*v[k-1]: 0.4980152565387012
# theta: [-0.75774511]
# np.cos(theta)[0]: 0.7263876055734702
# -np.sin(theta)*delta_t*v[k-1]: 0.5190506485023559
# theta: [-0.74545553]
# np.cos(theta)[0]: 0.7347789929104391
# -np.sin(theta)*delta_t*v[k-1]: 0.5522982806837684
# theta: [-0.71330727]
# np.cos(theta)[0]: 0.7562019419519289
# -np.sin(theta)*delta_t*v[k-1]: 0.5842543367494535
# theta: [-0.76945444]
# np.cos(theta)[0]: 0.7182903475801224
# -np.sin(theta)*delta_t*v[k-1]: 0.6036772850513761
# theta: [-0.78581757]
# np.cos(theta)[0]: 0.7068101513823769
# -np.sin(theta)*delta_t*v[k-1]: 0.60523315380004
# theta: [-0.6926468]
# np.cos(theta)[0]: 0.7695585279277417
# -np.sin(theta)*delta_t*v[k-1]: 0.5995592635713397
# theta: [-0.68454644]
# np.cos(theta)[0]: 0.7747059244334602
# -np.sin(theta)*delta_t*v[k-1]: 0.5970986398114899
# theta: [-0.72361759]
# np.cos(theta)[0]: 0.7494154306568214
# -np.sin(theta)*delta_t*v[k-1]: 0.63011968925261
# theta: [-0.79390322]
# np.cos(theta)[0]: 0.7010672981427855
# -np.sin(theta)*delta_t*v[k-1]: 0.594809660338731
# theta: [-0.75624514]
# np.cos(theta)[0]: 0.7274177012758513
# -np.sin(theta)*delta_t*v[k-1]: 0.6296655041915322
# theta: [-0.71835027]
# np.cos(theta)[0]: 0.7528925130227564
# -np.sin(theta)*delta_t*v[k-1]: 0.5624810726370252
# theta: [-0.74483749]
# np.cos(theta)[0]: 0.7351980728314969
# -np.sin(theta)*delta_t*v[k-1]: 0.5480765309976154
# theta: [-0.81122131]
# np.cos(theta)[0]: 0.6886133364591165
# -np.sin(theta)*delta_t*v[k-1]: 0.6604807395952713
# theta: [-0.80368902]
# np.cos(theta)[0]: 0.6940556338851538
# -np.sin(theta)*delta_t*v[k-1]: 0.672093952376576
# theta: [-0.78314889]
# np.cos(theta)[0]: 0.7086954680086426
# -np.sin(theta)*delta_t*v[k-1]: 0.5899573885816642
# theta: [-0.85561975]
# np.cos(theta)[0]: 0.65575073660879
# -np.sin(theta)*delta_t*v[k-1]: 0.6274975867519873
# theta: [-0.82081878]
# np.cos(theta)[0]: 0.6816223323176419
# -np.sin(theta)*delta_t*v[k-1]: 0.7993554010407563
# theta: [-0.79748415]
# np.cos(theta)[0]: 0.698509261557076
# -np.sin(theta)*delta_t*v[k-1]: 0.6791666803475204
# theta: [-0.75607695]
# np.cos(theta)[0]: 0.7275330960084323
# -np.sin(theta)*delta_t*v[k-1]: 0.6129307489455657
# theta: [-0.73225144]
# np.cos(theta)[0]: 0.7436710992091962
# -np.sin(theta)*delta_t*v[k-1]: 0.5190697269355445
# theta: [-0.75473398]
# np.cos(theta)[0]: 0.7284538169849643
# -np.sin(theta)*delta_t*v[k-1]: 0.6078556117152576
# theta: [-0.76507395]
# np.cos(theta)[0]: 0.7213311436204483
# -np.sin(theta)*delta_t*v[k-1]: 0.6243348141282784
# theta: [-0.81980259]
# np.cos(theta)[0]: 0.6823655264816382
# -np.sin(theta)*delta_t*v[k-1]: 0.6122375752618429
# theta: [-0.77152234]
# np.cos(theta)[0]: 0.7168500858336398
# -np.sin(theta)*delta_t*v[k-1]: 0.5970832466361667
# theta: [-0.79528333]
# np.cos(theta)[0]: 0.7000824817350412
# -np.sin(theta)*delta_t*v[k-1]: 0.5965485699060349
# theta: [-0.77228526]
# np.cos(theta)[0]: 0.7163179473825222
# -np.sin(theta)*delta_t*v[k-1]: 0.6283437100283394
# theta: [-0.72556695]
# np.cos(theta)[0]: 0.7481233356744216
# -np.sin(theta)*delta_t*v[k-1]: 0.6024978000932159
# theta: [-0.82995737]
# np.cos(theta)[0]: 0.6749072172880707
# -np.sin(theta)*delta_t*v[k-1]: 0.6163120799848378
# theta: [-0.78336727]
# np.cos(theta)[0]: 0.7085413790565516
# -np.sin(theta)*delta_t*v[k-1]: 0.615051498071169
# theta: [-0.79370615]
# np.cos(theta)[0]: 0.7012078107619469
# -np.sin(theta)*delta_t*v[k-1]: 0.549917200534465
# theta: [-0.79194463]
# np.cos(theta)[0]: 0.7024626113985475
# -np.sin(theta)*delta_t*v[k-1]: 0.7139594319803895
# theta: [-0.71609383]
# np.cos(theta)[0]: 0.7543756568778834
# -np.sin(theta)*delta_t*v[k-1]: 0.5940672176274134
# theta: [-0.71522242]
# np.cos(theta)[0]: 0.7549473978291659
# -np.sin(theta)*delta_t*v[k-1]: 0.5171544979427405
# theta: [-0.69463927]
# np.cos(theta)[0]: 0.7682846599042692
# -np.sin(theta)*delta_t*v[k-1]: 0.5050503058392795
# theta: [-0.64846547]
# np.cos(theta)[0]: 0.7970115403597288
# -np.sin(theta)*delta_t*v[k-1]: 0.5013045138855994
# theta: [-0.75226976]
# np.cos(theta)[0]: 0.7301398275141021
# -np.sin(theta)*delta_t*v[k-1]: 0.5745238734740502
# theta: [-0.75582079]
# np.cos(theta)[0]: 0.7277088217421445
# -np.sin(theta)*delta_t*v[k-1]: 0.5167243749504844
# theta: [-0.77470569]
# np.cos(theta)[0]: 0.7146269370539742
# -np.sin(theta)*delta_t*v[k-1]: 0.46887478276845157
# theta: [-0.74251013]
# np.cos(theta)[0]: 0.7367736862638424
# -np.sin(theta)*delta_t*v[k-1]: 0.6263203466063753
# theta: [-0.68463595]
# np.cos(theta)[0]: 0.7746493232240318
# -np.sin(theta)*delta_t*v[k-1]: 0.5808977162267953
# theta: [-0.62725422]
# np.cos(theta)[0]: 0.8096421235167798
# -np.sin(theta)*delta_t*v[k-1]: 0.4375358796186988
# theta: [-0.59722696]
# np.cos(theta)[0]: 0.8268982181887196
# -np.sin(theta)*delta_t*v[k-1]: 0.40266754061684434
# theta: [-0.63338879]
# np.cos(theta)[0]: 0.8060263835687504
# -np.sin(theta)*delta_t*v[k-1]: 0.46391779038298975
# theta: [-0.72992799]
# np.cos(theta)[0]: 0.7452224234031669
# -np.sin(theta)*delta_t*v[k-1]: 0.5422969708823574
# theta: [-0.67119098]
# np.cos(theta)[0]: 0.7830815281603121
# -np.sin(theta)*delta_t*v[k-1]: 0.5024630067470653
# theta: [-0.69136994]
# np.cos(theta)[0]: 0.7703732709981714
# -np.sin(theta)*delta_t*v[k-1]: 0.41033601058817337
# theta: [-0.66083258]
# np.cos(theta)[0]: 0.7894814872265425
# -np.sin(theta)*delta_t*v[k-1]: 0.42875239925874664
# theta: [-0.65371789]
# np.cos(theta)[0]: 0.7938282869889117
# -np.sin(theta)*delta_t*v[k-1]: 0.5369811912221178
# theta: [-0.57098943]
# np.cos(theta)[0]: 0.841366633596976
# -np.sin(theta)*delta_t*v[k-1]: 0.4127122846951389
# theta: [-0.63776699]
# np.cos(theta)[0]: 0.8034272995833014
# -np.sin(theta)*delta_t*v[k-1]: 0.43222220977923015
# theta: [-0.60165415]
# np.cos(theta)[0]: 0.8244004845454328
# -np.sin(theta)*delta_t*v[k-1]: 0.3599053576203437
# theta: [-0.64857986]
# np.cos(theta)[0]: 0.7969424432975395
# -np.sin(theta)*delta_t*v[k-1]: 0.46031680722136775
# theta: [-0.56458927]
# np.cos(theta)[0]: 0.8448084392330141
# -np.sin(theta)*delta_t*v[k-1]: 0.3228378659026196
# theta: [-0.56332736]
# np.cos(theta)[0]: 0.845482977957433
# -np.sin(theta)*delta_t*v[k-1]: 0.3045494395253978
# theta: [-0.99944874]
# np.cos(theta)[0]: 0.5407660924602344
# -np.sin(theta)*delta_t*v[k-1]: 0.6206540765438318
# theta: [-0.79210871]
# np.cos(theta)[0]: 0.7023458220626072
# -np.sin(theta)*delta_t*v[k-1]: 0.4733769892341835
# theta: [-1.08905914]
# np.cos(theta)[0]: 0.4633193508923918
# -np.sin(theta)*delta_t*v[k-1]: 0.5760238095431364
# theta: [-1.16009101]
# np.cos(theta)[0]: 0.39925609141725127
# -np.sin(theta)*delta_t*v[k-1]: 0.508113380453121
# theta: [-1.21023736]
# np.cos(theta)[0]: 0.35279731465669567
# -np.sin(theta)*delta_t*v[k-1]: 0.5686774748820604
# theta: [-1.123291]
# np.cos(theta)[0]: 0.43271786472757434
# -np.sin(theta)*delta_t*v[k-1]: 0.5810923763885241
# theta: [-2.0485255]
# np.cos(theta)[0]: -0.45976377047703615
# -np.sin(theta)*delta_t*v[k-1]: 0.5314367801466807
# theta: [3.03320953]
# np.cos(theta)[0]: -0.9941322965056808
# -np.sin(theta)*delta_t*v[k-1]: -0.06535750725394238
# theta: [2.02707282]
# np.cos(theta)[0]: -0.44060858173532325
# -np.sin(theta)*delta_t*v[k-1]: -0.5708389120227643
# theta: [1.42816194]
# np.cos(theta)[0]: 0.1421512411221674
# -np.sin(theta)*delta_t*v[k-1]: -0.5364477364400104
# theta: [1.13606602]
# np.cos(theta)[0]: 0.42116581382649126
# -np.sin(theta)*delta_t*v[k-1]: -0.558034070691272
# theta: [1.08321531]
# np.cos(theta)[0]: 0.46849016166941
# -np.sin(theta)*delta_t*v[k-1]: -0.46542020283091473
# theta: [1.07497051]
# np.cos(theta)[0]: 0.47575817947324545
# -np.sin(theta)*delta_t*v[k-1]: -0.5128233839442902
# theta: [1.05556232]
# np.cos(theta)[0]: 0.49273848745973525
# -np.sin(theta)*delta_t*v[k-1]: -0.4463438407171881
# theta: [1.07569275]
# np.cos(theta)[0]: 0.4751227892499765
# -np.sin(theta)*delta_t*v[k-1]: -0.5335340098650045
# theta: [1.03985342]
# np.cos(theta)[0]: 0.5063466643976182
# -np.sin(theta)*delta_t*v[k-1]: -0.4735091992696071
# theta: [0.70891667]
# np.cos(theta)[0]: 0.7590675844776551
# -np.sin(theta)*delta_t*v[k-1]: -0.32844623755635155
# theta: [0.50719556]
# np.cos(theta)[0]: 0.8741101368837632
# -np.sin(theta)*delta_t*v[k-1]: -0.21085238827106337
# theta: [0.11619161]
# np.cos(theta)[0]: 0.9932573463117849
# -np.sin(theta)*delta_t*v[k-1]: -0.06083745524773849
# theta: [-0.06689259]
# np.cos(theta)[0]: 0.9977635250933188
# -np.sin(theta)*delta_t*v[k-1]: 0.03178737015861338
# theta: [-0.12136377]
# np.cos(theta)[0]: 0.9926444527951908
# -np.sin(theta)*delta_t*v[k-1]: 0.054317486068426915
# theta: [-0.07426766]
# np.cos(theta)[0]: 0.9972434248997059
# -np.sin(theta)*delta_t*v[k-1]: 0.03331257309167721
# theta: [0.00176543]
# np.cos(theta)[0]: 0.9999984416315759
# -np.sin(theta)*delta_t*v[k-1]: -0.0007400516358419633
# theta: [0.03488437]
# np.cos(theta)[0]: 0.9993916020064726
# -np.sin(theta)*delta_t*v[k-1]: -0.014567276010880259
# theta: [0.03647158]
# np.cos(theta)[0]: 0.9993349858227076
# -np.sin(theta)*delta_t*v[k-1]: -0.016142200420598815
# theta: [0.04321685]
# np.cos(theta)[0]: 0.9990662973945734
# -np.sin(theta)*delta_t*v[k-1]: -0.016424670845671046
# theta: [0.16373256]
# np.cos(theta)[0]: 0.9866257432491952
# -np.sin(theta)*delta_t*v[k-1]: -0.08035359447600768
# theta: [0.20254276]
# np.cos(theta)[0]: 0.9795582419872358
# -np.sin(theta)*delta_t*v[k-1]: -0.09612535750258835
# theta: [0.26914507]
# np.cos(theta)[0]: 0.9639985817852632
# -np.sin(theta)*delta_t*v[k-1]: -0.11796970637907567
# theta: [0.2209863]
# np.cos(theta)[0]: 0.9756817352028978
# -np.sin(theta)*delta_t*v[k-1]: -0.08122007248745887
# theta: [0.25441182]
# np.cos(theta)[0]: 0.9678114933088191
# -np.sin(theta)*delta_t*v[k-1]: -0.092691431741459
# theta: [0.31829235]
# np.cos(theta)[0]: 0.9497712024797167
# -np.sin(theta)*delta_t*v[k-1]: -0.13229127069988328
# theta: [0.31969595]
# np.cos(theta)[0]: 0.9493310196373879
# -np.sin(theta)*delta_t*v[k-1]: -0.15315664044310398
# theta: [0.42824328]
# np.cos(theta)[0]: 0.9096966713579493
# -np.sin(theta)*delta_t*v[k-1]: -0.17004842339873083
# theta: [0.44966894]
# np.cos(theta)[0]: 0.9005910529742313
# -np.sin(theta)*delta_t*v[k-1]: -0.18123300572048803
# theta: [0.48616974]
# np.cos(theta)[0]: 0.8841290030028686
# -np.sin(theta)*delta_t*v[k-1]: -0.21549176869544062
# theta: [0.53899099]
# np.cos(theta)[0]: 0.8582270151404454
# -np.sin(theta)*delta_t*v[k-1]: -0.16059344806719747
# theta: [0.58955238]
# np.cos(theta)[0]: 0.8311896331351294
# -np.sin(theta)*delta_t*v[k-1]: -0.24665660451602786
# theta: [0.51833473]
# np.cos(theta)[0]: 0.8686454134858945
# -np.sin(theta)*delta_t*v[k-1]: -0.22555254356944726
# theta: [0.68858022]
# np.cos(theta)[0]: 0.7721489784238891
# -np.sin(theta)*delta_t*v[k-1]: -0.24235340859593624
# theta: [0.71300019]
# np.cos(theta)[0]: 0.7564028418993347
# -np.sin(theta)*delta_t*v[k-1]: -0.2982694584546191
# theta: [0.72415718]
# np.cos(theta)[0]: 0.7490580583009459
# -np.sin(theta)*delta_t*v[k-1]: -0.32202705343026394
# theta: [0.70089032]
# np.cos(theta)[0]: 0.7642683252913225
# -np.sin(theta)*delta_t*v[k-1]: -0.3180593739651625
# theta: [0.78496836]
# np.cos(theta)[0]: 0.7074106308371382
# -np.sin(theta)*delta_t*v[k-1]: -0.3084003321621111
# theta: [0.81479638]
# np.cos(theta)[0]: 0.6860165584740703
# -np.sin(theta)*delta_t*v[k-1]: -0.2970712632064772
# theta: [0.91237885]
# np.cos(theta)[0]: 0.6118659048412206
# -np.sin(theta)*delta_t*v[k-1]: -0.34981971369157394
# theta: [0.95971464]
# np.cos(theta)[0]: 0.5737537290564398
# -np.sin(theta)*delta_t*v[k-1]: -0.4563761956343508
# theta: [0.90371363]
# np.cos(theta)[0]: 0.6186967011807301
# -np.sin(theta)*delta_t*v[k-1]: -0.45884568494630357
# theta: [0.95371679]
# np.cos(theta)[0]: 0.5786557812365527
# -np.sin(theta)*delta_t*v[k-1]: -0.4126684957510795
# theta: [0.95710126]
# np.cos(theta)[0]: 0.5758921936996673
# -np.sin(theta)*delta_t*v[k-1]: -0.39753974433745765
# theta: [1.01302408]
# np.cos(theta)[0]: 0.5292974025260572
# -np.sin(theta)*delta_t*v[k-1]: -0.393422699169481
# theta: [1.01451721]
# np.cos(theta)[0]: 0.5280299925545
# -np.sin(theta)*delta_t*v[k-1]: -0.38937069536923213
# theta: [0.99270381]
# np.cos(theta)[0]: 0.5464273992262989
# -np.sin(theta)*delta_t*v[k-1]: -0.31545844100005804
# theta: [1.04752007]
# np.cos(theta)[0]: 0.49972066774707485
# -np.sin(theta)*delta_t*v[k-1]: -0.47462966370029175
# theta: [1.02339]
# np.cos(theta)[0]: 0.5204742997969805
# -np.sin(theta)*delta_t*v[k-1]: -0.3671026876855677
# theta: [1.04075604]
# np.cos(theta)[0]: 0.5055680976032796
# -np.sin(theta)*delta_t*v[k-1]: -0.521253980598671
# theta: [1.12457384]
# np.cos(theta)[0]: 0.43156099151129046
# -np.sin(theta)*delta_t*v[k-1]: -0.4873391944231031
# theta: [1.03228083]
# np.cos(theta)[0]: 0.5128621544918748
# -np.sin(theta)*delta_t*v[k-1]: -0.3898884100276899
# theta: [1.11775548]
# np.cos(theta)[0]: 0.437701643931752
# -np.sin(theta)*delta_t*v[k-1]: -0.47047891269749376
# theta: [1.14404169]
# np.cos(theta)[0]: 0.41391868502922247
# -np.sin(theta)*delta_t*v[k-1]: -0.3748556727833297
# theta: [1.1930975]
# np.cos(theta)[0]: 0.3687824751878175
# -np.sin(theta)*delta_t*v[k-1]: -0.5908849235076155
# theta: [1.16627388]
# np.cos(theta)[0]: 0.3935797948061317
# -np.sin(theta)*delta_t*v[k-1]: -0.35113415629983014
# theta: [1.25603475]
# np.cos(theta)[0]: 0.3095897746292255
# -np.sin(theta)*delta_t*v[k-1]: -0.4847146076731962
# theta: [1.30462091]
# np.cos(theta)[0]: 0.26304347611630374
# -np.sin(theta)*delta_t*v[k-1]: -0.6026822929560881
# theta: [1.19790675]
# np.cos(theta)[0]: 0.364307951677005
# -np.sin(theta)*delta_t*v[k-1]: -0.567624978723413
# theta: [1.30840797]
# np.cos(theta)[0]: 0.2593878974844999
# -np.sin(theta)*delta_t*v[k-1]: -0.5246169130299166
# theta: [1.30553851]
# np.cos(theta)[0]: 0.26215807725362283
# -np.sin(theta)*delta_t*v[k-1]: -0.5579950750407032
# theta: [1.33937963]
# np.cos(theta)[0]: 0.22935668015708263
# -np.sin(theta)*delta_t*v[k-1]: -0.48216571039799583
# theta: [1.29331424]
# np.cos(theta)[0]: 0.27393492370718053
# -np.sin(theta)*delta_t*v[k-1]: -0.5630905616013749
# theta: [1.34667465]
# np.cos(theta)[0]: 0.22225009049660216
# -np.sin(theta)*delta_t*v[k-1]: -0.6277913456139046
# theta: [1.50155755]
# np.cos(theta)[0]: 0.06918346604191748
# -np.sin(theta)*delta_t*v[k-1]: -0.6202812764898906
# theta: [1.42653738]
# np.cos(theta)[0]: 0.14375910906936565
# -np.sin(theta)*delta_t*v[k-1]: -0.5998120507016078
# theta: [1.39522595]
# np.cos(theta)[0]: 0.17466977271570291
# -np.sin(theta)*delta_t*v[k-1]: -0.7337487911642453
# theta: [1.48234543]
# np.cos(theta)[0]: 0.08833560601552405
# -np.sin(theta)*delta_t*v[k-1]: -0.49543168076157734
# theta: [1.44361899]
# np.cos(theta)[0]: 0.12683478736377846
# -np.sin(theta)*delta_t*v[k-1]: -0.6420640930548904
# theta: [1.49194979]
# np.cos(theta)[0]: 0.07876486460615495
# -np.sin(theta)*delta_t*v[k-1]: -0.6350864599428641
# theta: [1.41080082]
# np.cos(theta)[0]: 0.1593137743289307
# -np.sin(theta)*delta_t*v[k-1]: -0.5035003595093319
# theta: [1.47839452]
# np.cos(theta)[0]: 0.09227036961277765
# -np.sin(theta)*delta_t*v[k-1]: -0.6009181974488896
# theta: [1.46340906]
# np.cos(theta)[0]: 0.10718098308473953
# -np.sin(theta)*delta_t*v[k-1]: -0.6233379240969286
# theta: [1.47600552]
# np.cos(theta)[0]: 0.09464891348537376
# -np.sin(theta)*delta_t*v[k-1]: -0.4714170778477312
# theta: [1.46400584]
# np.cos(theta)[0]: 0.10658762978687016
# -np.sin(theta)*delta_t*v[k-1]: -0.6534998883065775
# theta: [1.57076433]
# np.cos(theta)[0]: 3.1996271996279344e-05
# -np.sin(theta)*delta_t*v[k-1]: -0.7574136837011564
# theta: [1.54488132]
# np.cos(theta)[0]: 0.025912107682866104
# -np.sin(theta)*delta_t*v[k-1]: -0.6407274160502682
# theta: [1.53590305]
# np.cos(theta)[0]: 0.034886192598207216
# -np.sin(theta)*delta_t*v[k-1]: -0.6328764744287473
# theta: [1.58492417]
# np.cos(theta)[0]: -0.01412736975923727
# -np.sin(theta)*delta_t*v[k-1]: -0.6076684045613008

# %% [markdown]
# Let's plot the resulting state estimates:

# %%
e_fig = plt.figure()
ax = e_fig.add_subplot(111)
ax.plot(x_est[:, 0], x_est[:, 1])
ax.set_xlabel('x [m]')
ax.set_ylabel('y [m]')
ax.set_title('Estimated trajectory')
plt.show()

e_fig = plt.figure()
ax = e_fig.add_subplot(111)
ax.plot(t[:], x_est[:, 2])
ax.set_xlabel('Time [s]')
ax.set_ylabel('theta [rad]')
ax.set_title('Estimated trajectory')
plt.show()

# %% [markdown]
# Are you satisfied wth your results? The resulting trajectory should closely resemble the ground truth, with minor "jumps" in the orientation estimate due to angle wrapping. If this is the case, run the code below to produce your solution file.

# %%
with open('submission.pkl', 'wb') as f:
    pickle.dump(x_est, f, pickle.HIGHEST_PROTOCOL)
